# %% [markdown]
# # Use print function
#
# Usamos la función *print* para mostrar mensajes e información.

# %%
welcome_msg: str = 'Hello World in Python3!'
print(welcome_msg)

# %% [markdown]
# ## Notebooks
# Jupyter nos permite crear documentos mediante celdas de código o celdas _markdown_. Agrega métodos abreviados para poder insertar
# celdas de manera rápida.
#
# Por otro lado incorpora comandos especiales que inician con el carácter %.

# %%
# enumera los elementos del directorio actual
# %ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n�mero de serie del volumen es: DA87-0AA7
#
#  Directorio de C:\Users\RodrigoAlvarez\Documents\Tutorials\Coursera\MicrosoftPythonDeveloper\c02_intro_data_analysis\notebooks
#
# 20/01/2026  05:16 p. m.    <DIR>          .
# 20/01/2026  05:16 p. m.    <DIR>          ..
# 20/01/2026  05:16 p. m.             1,631 _01_hello_world.ipynb
#                1 archivos          1,631 bytes
#                2 dirs  102,914,666,496 bytes libres
